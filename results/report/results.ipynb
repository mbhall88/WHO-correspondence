# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/hps/software/users/iqbal/mbhall/miniconda3/envs/who-correspondence/lib/python3.10/site-packages', '/hps/nobackup/iqbal/mbhall/WHO-correspondence/workflow/notebooks']); import pickle; snakemake = pickle.loads(b"\x80\x04\x95,\x0c\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c</hps/nobackup/iqbal/mbhall/WHO-correspondence/results/qc.csv\x94\x8cQ/hps/nobackup/iqbal/mbhall/WHO-correspondence/results/amr_predictions/who2021.csv\x94\x8cR/hps/nobackup/iqbal/mbhall/WHO-correspondence/results/amr_predictions/hunt2019.csv\x94\x8cR/hps/nobackup/iqbal/mbhall/WHO-correspondence/results/amr_predictions/hall2022.csv\x94\x8c\x14docs/samplesheet.csv\x94\x8c\x14docs/who-results.csv\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x02qc\x94K\x00N\x86\x94\x8c\x04csvs\x94K\x01K\x04\x86\x94\x8c\x0bsamplesheet\x94K\x04N\x86\x94\x8c\x0bwho_results\x94K\x05N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x1d\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h#)}\x94\x8c\x05_name\x94h\x1dsNt\x94bh\x1eh!h#\x85\x94R\x94(h#)}\x94h'h\x1esNt\x94bh\x13h\nh\x15h\x06\x8c\tNamedlist\x94\x93\x94)\x81\x94(h\x0bh\x0ch\re}\x94(h\x11}\x94h\x1b]\x94(h\x1dh\x1eeh\x1dh!h#\x85\x94R\x94(h#)}\x94h'h\x1dsNt\x94bh\x1eh!h#\x85\x94R\x94(h#)}\x94h'h\x1esNt\x94bubh\x17h\x0eh\x19h\x0fub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8cH/hps/nobackup/iqbal/mbhall/WHO-correspondence/results/report/results.csv\x94\x8cE/hps/nobackup/iqbal/mbhall/WHO-correspondence/results/report/plot.png\x94\x8cE/hps/nobackup/iqbal/mbhall/WHO-correspondence/results/report/plot.svg\x94e}\x94(h\x11}\x94(\x8c\x05table\x94K\x00N\x86\x94\x8c\x05plots\x94K\x01K\x03\x86\x94uh\x1b]\x94(h\x1dh\x1eeh\x1dh!h#\x85\x94R\x94(h#)}\x94h'h\x1dsNt\x94bh\x1eh!h#\x85\x94R\x94(h#)}\x94h'h\x1esNt\x94bhDh?hFh.)\x81\x94(h@hAe}\x94(h\x11}\x94h\x1b]\x94(h\x1dh\x1eeh\x1dh!h#\x85\x94R\x94(h#)}\x94h'h\x1dsNt\x94bh\x1eh!h#\x85\x94R\x94(h#)}\x94h'h\x1esNt\x94bubub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94(K\rK\x08\x86\x94M,\x01K\x0f\x8f\x94(\x8c\tOfloxacin\x94\x8c\rCiprofloxacin\x94\x90K_\x89}\x94(\x8c\x08previous\x94\x8c\x05Paper\x94\x8c\x07who2021\x94\x8c\x08WHO only\x94\x8c\x08hunt2019\x94\x8c\x07Mykrobe\x94\x8c\x08hall2022\x94\x8c\x08Combined\x94ue}\x94(h\x11}\x94(\x8c\x07figsize\x94K\x00N\x86\x94\x8c\x03dpi\x94K\x01N\x86\x94\x8c\rcov_threshold\x94K\x02N\x86\x94\x8c\x0cignore_drugs\x94K\x03N\x86\x94\x8c\rconf_interval\x94K\x04N\x86\x94\x8c\x14minor_is_susceptible\x94K\x05N\x86\x94\x8c\x0bpanel_names\x94K\x06N\x86\x94uh\x1b]\x94(h\x1dh\x1eeh\x1dh!h#\x85\x94R\x94(h#)}\x94h'h\x1dsNt\x94bh\x1eh!h#\x85\x94R\x94(h#)}\x94h'h\x1esNt\x94bhphahrM,\x01htK\x0fhvhbhxK_hz\x89h|heub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94}\x94(h\x11}\x94h\x1b]\x94(h\x1dh\x1eeh\x1dh!h#\x85\x94R\x94(h#)}\x94h'h\x1dsNt\x94bh\x1eh!h#\x85\x94R\x94(h#)}\x94h'h\x1esNt\x94bub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01M\x00\x08M\xe8\x03\x8c&/hps/scratch/lsf_tmpdir/hl-codon-04-01\x94e}\x94(h\x11}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06mem_mb\x94K\x02N\x86\x94\x8c\x07disk_mb\x94K\x03N\x86\x94\x8c\x06tmpdir\x94K\x04N\x86\x94uh\x1b]\x94(h\x1dh\x1eeh\x1dh!h#\x85\x94R\x94(h#)}\x94h'h\x1dsNt\x94bh\x1eh!h#\x85\x94R\x94(h#)}\x94h'h\x1esNt\x94bh\x9eK\x01h\xa0K\x01h\xa2M\x00\x08h\xa4M\xe8\x03h\xa6h\x9bub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8cJ/hps/nobackup/iqbal/mbhall/WHO-correspondence/results/report/results.ipynb\x94a}\x94(h\x11}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x1b]\x94(h\x1dh\x1eeh\x1dh!h#\x85\x94R\x94(h#)}\x94h'h\x1dsNt\x94bh\x1eh!h#\x85\x94R\x94(h#)}\x94h'h\x1esNt\x94bh\xb8h\xb5ub\x8c\x06config\x94}\x94(\x8c\x0bsamplesheet\x94\x8c\x14docs/samplesheet.csv\x94\x8c\x0bwho_results\x94\x8c\x14docs/who-results.csv\x94\x8c\treference\x94\x8c\x18resources/NC_000962.3.fa\x94\x8c\x07genbank\x94\x8c\x18resources/NC_000962.3.gb\x94\x8c\x08features\x94\x8c\x1aresources/NC_000962.3.gff3\x94\x8c\x0cexpert_rules\x94\x8c\x1aresources/expert_rules.csv\x94\x8c\x13background_variants\x94\x8c0resources/mykrobe_background_variant_vcfs.tar.gz\x94\x8c\nfull_panel\x94\x8c\x12docs/who-panel.tsv\x94\x8c\x0fpanel_kmer_size\x94K\x15\x8c\rcov_threshold\x94K\x0f\x8c\rconf_interval\x94K_\x8c\x14minor_is_susceptible\x94\x89\x8c\x06grades\x94]\x94K\x02a\x8c\ncontainers\x94}\x94(\x8c\x04base\x94\x8c\x11docker://bash:5.1\x94\x8c\x08fastq_dl\x94\x8c*docker://quay.io/mbhall88/fastq-dl:4fe5719\x94\x8c\tclockwork\x94\x8c+docker://quay.io/mbhall88/clockwork:fe62f00\x94\x8c\x07mykrobe\x94\x8c)docker://quay.io/mbhall88/mykrobe:b6d0f37\x94\x8c\x05fastp\x94\x8c7docker://quay.io/biocontainers/fastp:0.23.2--h79da9fb_0\x94\x8c\x06seqkit\x94\x8c7docker://quay.io/biocontainers/seqkit:2.2.0--h9ee0642_0\x94\x8c\x06python\x94\x8c$docker://python:3.10.4-slim-bullseye\x94uu\x8c\x04rule\x94\x8c\x06report\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c@/hps/nobackup/iqbal/mbhall/WHO-correspondence/workflow/notebooks\x94ub."); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/hps/nobackup/iqbal/mbhall/WHO-correspondence');
######## snakemake preamble end #########

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict, Counter
from pathlib import Path
from itertools import product
from enum import Enum
from dataclasses import dataclass
from typing import Tuple
import numpy as np
from scipy import stats
from math import sqrt

plt.style.use("ggplot")
if "snakemake" in locals() or "snakemake" in globals():
    plt.rcParams['figure.figsize'] = snakemake.params.figsize
    plt.rcParams['figure.dpi'] = snakemake.params.dpi
    csvs = snakemake.input.csvs
    qc = pd.read_csv(snakemake.input.qc)
    cov_threshold = snakemake.params.cov_threshold
    phenotypes = pd.read_csv(snakemake.input.samplesheet, index_col="run")
    ignore_drugs = snakemake.params.ignore_drugs
    CONF = snakemake.params.conf_interval
    minor_is_susceptible = snakemake.params.minor_is_susceptible
    panel_names = snakemake.params.panel_names
    outpath = snakemake.output.table
    plots = snakemake.output.plots
    who_results = pd.read_csv(snakemake.input.who_results)
else:
    plt.rcParams['figure.figsize'] = (13, 8)
    plt.rcParams['figure.dpi'] = 300
    csvs = list(Path("../../results/amr_predictions/").glob("*.csv"))
    qc = pd.read_csv("../../results/qc.csv")
    cov_threshold = 15
    phenotypes = pd.read_csv("../../docs/samplesheet.csv", index_col="run")
    ignore_drugs = {"Ciprofloxacin", "Ofloxacin"}
    CONF = 0.95
    minor_is_susceptible = False
    panel_names = {
        "previous": "Walker et al.",
        "who2021": "WHO only",
        "hunt2019": "Mykrobe",
        "hall2022": "Combined"
    }
    outpath = "table.csv"
    plots = ["plot.png"]
    who_results = pd.read_csv("../../docs/who-results.csv")

# %%
len(csvs)
# Out:
# 3

# %%
frames = []
for p in csvs:
    frames.append(pd.read_csv(p))

df = pd.concat(frames).reset_index(drop=True)

# %%
passed_qc = set(qc.query("coverage >= @cov_threshold")["run"])
len(passed_qc)
# Out:
# 8160

# %% [markdown]
# Remove DST results for any sample with Illumina coverage below the threshold.

# %%
df = df.query("run in @passed_qc")

# %%
class Prediction(Enum):
    Resistant = "R"
    Susceptible = "S"
    MinorResistance = "r"

    def __str__(self) -> str:
        return self.value
    
class Classification(Enum):
    TruePositive = "TP"
    FalsePositive = "FP"
    TrueNegative = "TN"
    FalseNegative = "FN"

    def __str__(self) -> str:
        return self.value
    
class Classification(Enum):
    TruePositive = "TP"
    FalsePositive = "FP"
    TrueNegative = "TN"
    FalseNegative = "FN"

    def __str__(self) -> str:
        return self.value


class Classifier:
    def __init__(
        self,
        minor_is_susceptible: bool = False,
    ):
        self.minor_is_susceptible = minor_is_susceptible
        self.susceptible = {Prediction.Susceptible}
        self.resistant = {Prediction.Resistant}
        if self.minor_is_susceptible:
            self.susceptible.add(Prediction.MinorResistance)
        else:
            self.resistant.add(Prediction.MinorResistance)


    def from_predictions(
        self, y_true: Prediction, y_pred: Prediction
    ) -> Classification:
        if y_true in self.susceptible:
            expected_susceptible = True
        elif y_true in self.resistant:
            expected_susceptible = False
        else:
            raise NotImplementedError(f"Don't know how to classify {y_true} calls yet")

        if y_pred in self.susceptible:
            called_susceptible = True
        elif y_pred in self.resistant:
            called_susceptible = False
        else:
            raise NotImplementedError(f"Don't know how to classify {y_pred} calls yet")

        if expected_susceptible and called_susceptible:
            return Classification.TrueNegative
        elif expected_susceptible and not called_susceptible:
            return Classification.FalsePositive
        elif not expected_susceptible and not called_susceptible:
            return Classification.TruePositive
        else:
            return Classification.FalseNegative

@dataclass
class ConfusionMatrix:
    tp: int = 0
    tn: int = 0
    fp: int = 0
    fn: int = 0

    def ravel(self) -> Tuple[int, int, int, int]:
        """Return the matrix as a flattened tuple.
        The order of return is TN, FP, FN, TP
        """
        return self.tn, self.fp, self.fn, self.tp

    def as_matrix(self) -> np.ndarray:
        """Returns a 2x2 matrix [[TN, FP], [FN, TP]]"""
        return np.array([[self.tn, self.fp], [self.fn, self.tp]])

    def num_positive(self) -> int:
        """Number of TPs and FNs - i.e. actual condition positive"""
        return self.tp + self.fn

    def num_negative(self) -> int:
        """Number of TNs and FPs - i.e. actual condition negative"""
        return self.tn + self.fp

    def ppv(self) -> Tuple[float, float, float]:
        """Also known as precision"""
        try:
            ppv = self.tp / (self.tp + self.fp)
            lwr_bound, upr_bound = confidence_interval(n_s=self.tp, n_f=self.fp)
            return ppv, lwr_bound, upr_bound
        except ZeroDivisionError:
            return [None, None, None]

    def npv(self) -> Tuple[float, float, float]:
        """Negative predictive value"""
        try:
            npv = self.tn / (self.tn + self.fn)
            lwr_bound, upr_bound = confidence_interval(n_s=self.tn, n_f=self.fn)
            return npv, lwr_bound, upr_bound
        except ZeroDivisionError:
            return [None, None, None]

    def sensitivity(self) -> Tuple[float, float, float]:
        """Also known as recall and true positive rate (TPR)"""
        try:
            sn =  self.tp / self.num_positive()
            lwr_bound, upr_bound = confidence_interval(n_s=self.tp, n_f=self.fn)
            return sn, lwr_bound, upr_bound
        except ZeroDivisionError:
            return None, None, None

    def specificity(self) -> Tuple[float, float, float]:
        """Also known as selectivity and true negative rate (TNR)"""
        try:
            sp = self.tn / self.num_negative()
            lwr_bound, upr_bound = confidence_interval(n_s=self.tn, n_f=self.fp)
            return sp, lwr_bound, upr_bound
        except ZeroDivisionError:
            return None, None, None

    def fnr(self) -> Tuple[float, float, float]:
        """False negative rate or VME (very major error rate)"""
        try:
            fnr = self.fn / self.num_positive()
            lwr_bound, upr_bound = confidence_interval(n_s=self.fn, n_f=self.tp)
            return fnr, lwr_bound, upr_bound
        except ZeroDivisionError:
            return [None, None, None]

    def fpr(self) -> Tuple[float, float, float]:
        """False positive rate or ME (major error rate)"""
        try:
            fpr = self.fp / self.num_negative()
            lwr_bound, upr_bound = confidence_interval(n_s=self.fp, n_f=self.tn)
            return fpr, lwr_bound, upr_bound
        except ZeroDivisionError:
            return [None, None, None]

    def f_score(self, beta: float = 1.0) -> float:
        """Harmonic mean of precision and recall.
        When beta is set to 0, you get precision. When beta is set to 1, you get the
        unweighted F-score which is the harmonic mean of precision and recall. Setting
        beta to 2 weighs recall twice as much as precision. Setting beta to 0.5 weighs
        precision twice as much as recall.
        """
        ppv = self.precision()
        tpr = self.recall()
        if ppv is None or tpr is None:
            return None
        beta2 = beta ** 2

        return ((beta2 + 1) * ppv * tpr) / ((beta2 * ppv) + tpr)

    @staticmethod
    def from_series(s: pd.Series) -> "ConfusionMatrix":
        tp = s.get("TP", 0)
        fp = s.get("FP", 0)
        fn = s.get("FN", 0)
        tn = s.get("TN", 0)
        return ConfusionMatrix(tp=tp, fn=fn, fp=fp, tn=tn)


def confidence_interval(n_s: int, n_f: int, conf: float = CONF) -> Tuple[float, float]:
    """Calculate the Wilson score interval.
    Equation take from https://en.wikipedia.org/wiki/Binomial_proportion_confidence_interval#Wilson_score_interval
    n_s: Number of successes or, in the case of confusion matrix statistics, the numerator
    n_f: Number of failures or, in the case of confusion matrix statistics, the denominator minus the numerator
    conf: the confidence level. i.e. 0.95 is 95% confidence
    """
    n = n_f + n_s
    z = stats.norm.ppf(1 - (1 - conf) / 2)  # two-sided
    z2 = z ** 2
    nz2 = n + z2
    A = (n_s + (0.5 * z2)) / nz2
    B = z / nz2
    C = sqrt(((n_s * n_f) / n) + (z2 / 4))
    CI = B * C
    return A - CI, A + CI


def round_up_to_base(x, base=10):
    return int(x + (base - x) % base)


def round_down_to_base(x, base=10):
    return int(x - (x % base))

# %%
df = df.query("drug not in @ignore_drugs")

# %%
classifier = Classifier(minor_is_susceptible=minor_is_susceptible)
classifications = []
for _, row in df.iterrows():
    drug = row["drug"].lower()
    y_true = phenotypes.at[row["run"], drug]
    if pd.isna(y_true):
        classifications.append(None)
    else:
        y_true = Prediction(y_true)
        y_pred = Prediction(row["prediction"])
        clf = classifier.from_predictions(y_true, y_pred)
        classifications.append(str(clf))

# %%
df["classification"] = classifications

# %%
df
# Out:
#                run     biosample   bioproject     panel          drug  \
# 0        ERR036186   SAMEA897802    PRJEB2358   who2021     Delamanid
# 1        ERR036186   SAMEA897802    PRJEB2358   who2021     Kanamycin
# 2        ERR036186   SAMEA897802    PRJEB2358   who2021      Amikacin
# 3        ERR036186   SAMEA897802    PRJEB2358   who2021    Ethambutol
# 4        ERR036186   SAMEA897802    PRJEB2358   who2021   Ethionamide
# ...            ...           ...          ...       ...           ...
# 324499  SRR7131298  SAMN09090624  PRJNA438921  hall2022  Levofloxacin
# 324500  SRR7131298  SAMN09090624  PRJNA438921  hall2022  Pyrazinamide
# 324501  SRR7131298  SAMN09090624  PRJNA438921  hall2022     Linezolid
# 324502  SRR7131298  SAMN09090624  PRJNA438921  hall2022    Rifampicin
# 324503  SRR7131298  SAMN09090624  PRJNA438921  hall2022   Capreomycin
#
#        prediction classification
# 0               S           None
# 1               S           None
# 2               S           None
# 3               S             TN
# 4               S           None
# ...           ...            ...
# 324499          S           None
# 324500          S           None
# 324501          S           None
# 324502          S             TN
# 324503          S           None
#
# [285600 rows x 7 columns]

# %%
cms = defaultdict()
DRUGS = set(df["drug"])
PANELS = set(df["panel"])

for drug, panel in product(DRUGS, PANELS):
    s = df.query("drug == @drug and panel == @panel").value_counts(
        subset=["classification"]
    )
    cm = ConfusionMatrix.from_series(s)
    cms[(drug, panel)] = cm
    
DRUGS = sorted(DRUGS)

# %%
metrics = []
for (drug, panel), cm in cms.items():
    sn = cm.sensitivity()[0]
    sp = cm.specificity()[0]
    metrics.append((drug, panel, sn, sp))

summary_cols = [
    "drug",
    "panel",
    "Sensitivity",
    "Specificity",
]

summary = pd.DataFrame(
    metrics,
    columns=summary_cols,
).melt(id_vars=["drug", "panel"], var_name="metric")

# %%
counts = df.groupby(["drug", "panel", "classification"])["run"].count()
table = summary.set_index(["drug", "panel", "metric"])["value"].unstack().reset_index()

for clf in ["TP", "FP", "FN", "TN"]:
    table[clf] = 0

for i, row in table.iterrows():
    ix = (row["drug"], row["panel"])
    cm = cms[ix]
    table.at[i, "TP"] = cm.tp
    table.at[i, "FP"] = cm.fp
    table.at[i, "TN"] = cm.tn
    table.at[i, "FN"] = cm.fn
    
for k in ["drug", "panel"]:
    table[k] = table[k].str.capitalize()

table.fillna("-", inplace=True)
summary_cols = ["drug", "panel", "Sensitivity", "Specificity", "TP", "TN", "FN", "FP"]
table = table[summary_cols]

# %%
rows = []
ci_str = (
    lambda tup: f"{tup[0]:.1%} ({tup[1]*100:.1f}-{tup[2]:.1%})"
    if tup[0] is not None
    else "-"
)
for i, row in table.iterrows():
    cm = ConfusionMatrix(tp=row["TP"], fp=row["FP"], tn=row["TN"], fn=row["FN"])
    sn = cm.sensitivity()
    sp = cm.specificity()
    fn_str = f"{cm.fn}({cm.num_positive()})"
    fp_str = f"{cm.fp}({cm.num_negative()})"
    rows.append(
        (
            row["drug"].capitalize(),
            panel_names[row["panel"].lower()],
            fn_str,
            fp_str,
            ci_str(sn),
            ci_str(sp),
        )
    )
pretty_cols = [
    "Drug",
    "Catalogue",
    "FN(R)",
    "FP(S)",
    "Sensitivity (95% CI)",
    "Specificity (95% CI)",
]
table = pd.DataFrame(rows, columns=pretty_cols)

# %%
paper_data = []
for _, row in who_results.iterrows():
    panel = panel_names["previous"]
    sn = f"{row['sensitivity']}% ({row['sensitivity_lower_bound']}%-{row['sensitivity_upper_bound']}%)"
    sp = f"{row['specificity']}% ({row['specificity_lower_bound']}%-{row['specificity_upper_bound']}%)"
    paper_data.append((row["drug"].capitalize(), panel, "-", "-", sn, sp))
paper_tbl = pd.DataFrame(paper_data, columns=table.columns)

# %%
table = pd.concat([paper_tbl, table]).reset_index(drop=True).sort_values(["Drug", "Catalogue"], ascending=[True, False]).reset_index(drop=True)
table
# Out:
#             Drug Catalogue      FN(R)      FP(S) Sensitivity (95% CI)  \
# 0       Amikacin  WHO only    48(311)   38(3436)     84.6% (nan-nan%)
# 1       Amikacin     Paper          -          -  77.3% (74.9%-79.5%)
# 2       Amikacin   Mykrobe    49(311)   16(3436)     84.2% (nan-nan%)
# 3       Amikacin  Combined    48(311)   38(3436)     84.6% (nan-nan%)
# 4    Capreomycin  WHO only    99(319)   42(3603)     69.0% (nan-nan%)
# 5    Capreomycin     Paper          -          -  69.4% (66.4%-72.3%)
# 6    Capreomycin   Mykrobe    98(319)   39(3603)     69.3% (nan-nan%)
# 7    Capreomycin  Combined    99(319)   42(3603)     69.0% (nan-nan%)
# 8      Delamanid  WHO only     42(42)     0(492)      0.0% (nan-nan%)
# 9      Delamanid     Paper          -          -    6.1% (2.0%-13.7%)
# 10     Delamanid   Mykrobe       0(0)       0(0)                    -
# 11     Delamanid  Combined     42(42)     0(492)      0.0% (nan-nan%)
# 12    Ethambutol  WHO only   115(543)  216(1636)     78.8% (nan-nan%)
# 13    Ethambutol     Paper          -          -  86.7% (85.7%-87.6%)
# 14    Ethambutol   Mykrobe   115(543)  225(1636)     78.8% (nan-nan%)
# 15    Ethambutol  Combined   109(543)  227(1636)     79.9% (nan-nan%)
# 16   Ethionamide  WHO only    44(229)    98(562)     80.8% (nan-nan%)
# 17   Ethionamide     Paper          -          -  75.7% (74.1%-77.3%)
# 18   Ethionamide   Mykrobe       0(0)       0(0)                    -
# 19   Ethionamide  Combined    44(229)    98(562)     80.8% (nan-nan%)
# 20     Isoniazid  WHO only  418(2313)  128(5361)     81.9% (nan-nan%)
# 21     Isoniazid     Paper          -          -  91.2% (90.7%-91.7%)
# 22     Isoniazid   Mykrobe  350(2313)  116(5361)     84.9% (nan-nan%)
# 23     Isoniazid  Combined  339(2313)  141(5361)     85.3% (nan-nan%)
# 24     Kanamycin  WHO only    77(361)   36(3749)     78.7% (nan-nan%)
# 25     Kanamycin     Paper          -          -  73.2% (70.9%-75.4%)
# 26     Kanamycin   Mykrobe   119(361)   22(3749)     67.0% (nan-nan%)
# 27     Kanamycin  Combined    77(361)   36(3749)     78.7% (nan-nan%)
# 28  Levofloxacin  WHO only     10(91)     19(35)     89.0% (nan-nan%)
# 29  Levofloxacin     Paper          -          -  84.4% (83.1%-85.7%)
# 30  Levofloxacin   Mykrobe       0(0)       0(0)                    -
# 31  Levofloxacin  Combined     10(91)     19(35)     89.0% (nan-nan%)
# 32     Linezolid  WHO only     12(12)     0(412)      0.0% (nan-nan%)
# 33     Linezolid     Paper          -          -  38.2% (29.6%-47.4%)
# 34     Linezolid   Mykrobe       0(0)       0(0)                    -
# 35     Linezolid  Combined     12(12)     0(412)      0.0% (nan-nan%)
# 36  Moxifloxacin  WHO only    24(262)  129(4369)     90.8% (nan-nan%)
# 37  Moxifloxacin     Paper          -          -  87.7% (86.2%-89.2%)
# 38  Moxifloxacin   Mykrobe    26(262)  125(4369)     90.1% (nan-nan%)
# 39  Moxifloxacin  Combined    24(262)  129(4369)     90.8% (nan-nan%)
# 40  Pyrazinamide  WHO only   301(913)   79(3712)     67.0% (nan-nan%)
# 41  Pyrazinamide     Paper          -          -  72.3% (70.5%-74.2%)
# 42  Pyrazinamide   Mykrobe   385(913)   89(3712)     57.8% (nan-nan%)
# 43  Pyrazinamide  Combined   278(913)   98(3712)     69.6% (nan-nan%)
# 44    Rifampicin  WHO only  161(1856)  147(6086)     91.3% (nan-nan%)
# 45    Rifampicin     Paper          -          -  93.8% (93.3%-94.2%)
# 46    Rifampicin   Mykrobe  170(1856)  133(6086)     90.8% (nan-nan%)
# 47    Rifampicin  Combined  161(1856)  151(6086)     91.3% (nan-nan%)
# 48  Streptomycin  WHO only   181(689)  127(1349)     73.7% (nan-nan%)
# 49  Streptomycin     Paper          -          -  82.4% (81.3%-83.5%)
# 50  Streptomycin   Mykrobe   201(689)   93(1349)     70.8% (nan-nan%)
# 51  Streptomycin  Combined   156(689)  151(1349)     77.4% (nan-nan%)
#
#      Specificity (95% CI)
# 0        98.9% (nan-nan%)
# 1     99.0% (98.9%-99.2%)
# 2        99.5% (nan-nan%)
# 3        98.9% (nan-nan%)
# 4        98.8% (nan-nan%)
# 5     98.3% (98.0%-98.6%)
# 6        98.9% (nan-nan%)
# 7        98.8% (nan-nan%)
# 8       100.0% (nan-nan%)
# 9   100.0% (99.9%-100.0%)
# 10                      -
# 11      100.0% (nan-nan%)
# 12       86.8% (nan-nan%)
# 13    93.3% (93.0%-93.6%)
# 14       86.2% (nan-nan%)
# 15       86.1% (nan-nan%)
# 16       82.6% (nan-nan%)
# 17    91.4% (90.8%-91.9%)
# 18                      -
# 19       82.6% (nan-nan%)
# 20       97.6% (nan-nan%)
# 21    98.4% (98.2%-98.6%)
# 22       97.8% (nan-nan%)
# 23       97.4% (nan-nan%)
# 24       99.0% (nan-nan%)
# 25    98.4% (98.2%-98.6%)
# 26       99.4% (nan-nan%)
# 27       99.0% (nan-nan%)
# 28       45.7% (nan-nan%)
# 29    98.3% (98.1%-98.5%)
# 30                      -
# 31       45.7% (nan-nan%)
# 32      100.0% (nan-nan%)
# 33    99.8% (99.8%-99.9%)
# 34                      -
# 35      100.0% (nan-nan%)
# 36       97.0% (nan-nan%)
# 37    91.6% (91.0%-92.1%)
# 38       97.1% (nan-nan%)
# 39       97.0% (nan-nan%)
# 40       97.9% (nan-nan%)
# 41    98.8% (98.6%-99.0%)
# 42       97.6% (nan-nan%)
# 43       97.4% (nan-nan%)
# 44       97.6% (nan-nan%)
# 45    98.2% (98.0%-98.3%)
# 46       97.8% (nan-nan%)
# 47       97.5% (nan-nan%)
# 48       90.6% (nan-nan%)
# 49    95.4% (95.0%-95.8%)
# 50       93.1% (nan-nan%)
# 51       88.8% (nan-nan%)

# %%
sn_data = []
sp_data = []
for drug, panel in product(DRUGS, PANELS):
    s = df.query("drug == @drug and panel == @panel").value_counts(
        subset=["classification"]
    )
    cm = ConfusionMatrix.from_series(s)
    sn = cm.sensitivity()
    sp = cm.specificity()
    sn_data.append((drug, panel, *sn))
    sp_data.append((drug, panel, *sp))
    
sn_df = pd.DataFrame(sn_data, columns=["drug", "panel", "value", "lower", "upper"])
sp_df = pd.DataFrame(sp_data, columns=["drug", "panel", "value", "lower", "upper"])

# %%
DRUGS
# Out:
# ['Amikacin',
#  'Capreomycin',
#  'Delamanid',
#  'Ethambutol',
#  'Ethionamide',
#  'Isoniazid',
#  'Kanamycin',
#  'Levofloxacin',
#  'Linezolid',
#  'Moxifloxacin',
#  'Pyrazinamide',
#  'Rifampicin',
#  'Streptomycin']

# %%
sensitivities = []
for d in DRUGS:
    sensitivities.append(np.mean(sn_df.query("drug==@d")["value"]))
sensitivities = np.array(sensitivities)
drugix = np.array(list(reversed(np.argsort(sensitivities))))
ordered_drugs = np.array(DRUGS)[drugix]

# %%
def sort_drugs(a):
    xs = [d.lower() for d in ordered_drugs.tolist()]
    out = []
    c = Counter()
    for x in a:
        i = xs.index(x.lower())
        d = xs[i]
        c[d] += 1
        out.append((i, c[d]))
    return out

# %%
sn_df = sn_df.sort_values(by="drug", key=sort_drugs).reset_index(drop=True)
sp_df = sp_df.sort_values(by="drug", key=sort_drugs).reset_index(drop=True)

# %%
s = """AMK amikacin
BDQ bedaquiline
CAP capreomycin
CFZ clofazimine
CFX ciprofloxacin
DLM delamanid
EMB ethambutol
ETO ethionamide
FQ fluoroquinolone
INH isoniazid
KAN kanamycin
LFX levofloxacin
LZD linezolid
MFX moxifloxacin
OFX ofloxacin
PTO prothionamide
PZA pyrazinamide
RIF rifampicin
STM streptomycin"""
abbrev = dict()
for line in s.splitlines():
    ab, d = line.split()
    abbrev[d.capitalize()] = ab
abbrev
# Out:
# {'Amikacin': 'AMK',
#  'Bedaquiline': 'BDQ',
#  'Capreomycin': 'CAP',
#  'Clofazimine': 'CFZ',
#  'Ciprofloxacin': 'CFX',
#  'Delamanid': 'DLM',
#  'Ethambutol': 'EMB',
#  'Ethionamide': 'ETO',
#  'Fluoroquinolone': 'FQ',
#  'Isoniazid': 'INH',
#  'Kanamycin': 'KAN',
#  'Levofloxacin': 'LFX',
#  'Linezolid': 'LZD',
#  'Moxifloxacin': 'MFX',
#  'Ofloxacin': 'OFX',
#  'Prothionamide': 'PTO',
#  'Pyrazinamide': 'PZA',
#  'Rifampicin': 'RIF',
#  'Streptomycin': 'STM'}

# %%
fig, axR = plt.subplots(figsize=(13, 8), dpi=300)
axS = axR.twiny()
ggplot_cm = plt.rcParams["axes.prop_cycle"].by_key()["color"]
red = ggplot_cm[0]
blue = ggplot_cm[1]
purple = ggplot_cm[2]
black = ggplot_cm[3]
yellow = ggplot_cm[4]
green = ggplot_cm[5]
edgecol = "black"
cmap = [purple, black, yellow]
# plot details
bar_width = 0.2
epsilon = 0.05
line_width = 0.5
fs = 12
rotate = 0
capsize = 2
alpha = 1.0
bar_alpha = 0.6
hatch = ""

all_positions = []
i = -1
for panel in panel_names:
    if panel == "previous":
        continue
    i += 1
    ix = (d, panel)
    panel_sn_df = sn_df.query("panel==@panel")
    sn_ys = panel_sn_df["value"] * 100
    sn_lb = sn_ys - panel_sn_df["lower"] * 100
    sn_ub = panel_sn_df["upper"] * 100 - sn_ys
    
    positions = [p + ((bar_width + epsilon) * i) for p in np.arange(len(sn_ys))]
    if panel == "who2021":
        who_positions = np.array(positions)
        
    all_positions.append(positions)
    
    colour = cmap[i]
    label = panel_names[panel.lower()]

    # resistance bar plots
    sn_bar = axR.bar(
        positions,
        sn_ys,
        bar_width,
        yerr=[sn_lb, sn_ub],
        color=colour,
        edgecolor=edgecol,
        linewidth=line_width,
        capsize=capsize,
        alpha=bar_alpha,
        label=label,
    )

    panel_sp_df = sp_df.query("panel==@panel")
    sp_ys = panel_sp_df["value"] * 100
    sp_lb = sp_ys - panel_sp_df["lower"] * 100
    sp_ub = panel_sp_df["upper"] * 100 - sp_ys
    sp_ub = [min(100, x) for x in sp_ub]
    
    sp_bar = axS.bar(
        positions,
        height=-(100-sp_ys),
        bottom=100,
        width=bar_width*0.75,
        yerr=[sp_lb, sp_ub],
        alpha=bar_alpha,
        color=colour,
        edgecolor=edgecol,
        linewidth=line_width,
        capsize=capsize,
        error_kw=dict(barsabove=True),
        label=label,
    )
    


# add errorbars for paper sensitivity
paper_cat = panel_names["previous"]
paper_df = who_results.sort_values(by="drug", key=sort_drugs).reset_index(drop=True)
offset = 0.05
xs = who_positions-offset#[np.mean(ps)-0.1 for ps in zip(*all_positions)]
metric = "sensitivity"
ys = np.array(paper_df[metric])
yerr_l = ys - paper_df[f"{metric}_lower_bound"]
yerr_u = paper_df[f"{metric}_upper_bound"] - ys
yerr_u = [min(100, x) for x in yerr_u]
axR.errorbar(
    xs, 
    ys, 
    yerr=[yerr_l, yerr_u], 
    color=red, 
    capsize=capsize, 
    fmt=".--", 
    alpha=0.9, 
    linewidth=line_width,
    label=metric.capitalize()
)

# add errorbars for paper specificity
paper_cat = panel_names["previous"]
paper_df = who_results.sort_values(by="drug", key=sort_drugs).reset_index(drop=True)
metric = "specificity"
ys = np.array(paper_df[metric])
yerr_l = ys - paper_df[f"{metric}_lower_bound"]
yerr_u = paper_df[f"{metric}_upper_bound"] - ys
yerr_u = [min(100, x) for x in yerr_u]
axR.errorbar(
    xs, 
    ys, 
    yerr=[yerr_l, yerr_u], 
    color=blue, 
    capsize=capsize, 
    fmt=".--", 
    alpha=0.9, 
    linewidth=line_width,
    label=metric.capitalize()
)
    
labels = [abbrev[d] for d in ordered_drugs]
label_pos = [np.mean(ps) for ps in zip(*all_positions)]
plt.xticks(label_pos, labels, rotation=rotate, fontsize=fs)
axR.set_ylabel("value (%)")
yticks = [30, 40, 50, 60, 70, 80, 85, 90, 95, 100]
axR.set_yticks(yticks)
axR.set_yticklabels(yticks)
axR.set_xticks(label_pos)
axR.set_xticklabels(axS.get_xticklabels(), rotation=rotate, fontsize=fs)
axR.tick_params("both", labelsize=fs)

plt.text(-0.6, 2,
    "Sensitivity ➜", 
    rotation="vertical", 
    fontsize=fs,
)
plt.text(12.9, 82,
    "Specificity ➜", 
    rotation=270, 
    fontsize=fs,
)

leghandles, leglabels = axR.get_legend_handles_labels()
legend_props = dict(loc="upper right", prop=dict(size=fs), frameon=False, title_fontproperties=dict(size=fs-1, weight="bold"))
axR.legend(leghandles[:-2], leglabels[:-2], title="Catalogue", bbox_to_anchor=(1, 0.84), **legend_props)
axS.legend(leghandles[-2:], leglabels[-2:], title="Walker et al.", bbox_to_anchor=(1, 0.68), **legend_props)
axS.grid(False)
axR.grid(False, axis="x",)
_ = axR.set_xlabel("Drug", fontsize=fs+2)
# Out:
# /hps/nobackup/iqbal/mbhall/WHO-correspondence/.snakemake/conda/96fd00f4d1a3b1a39abc7b0eee92225d/lib/python3.10/site-packages/numpy/core/_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# /hps/nobackup/iqbal/mbhall/WHO-correspondence/.snakemake/conda/96fd00f4d1a3b1a39abc7b0eee92225d/lib/python3.10/site-packages/numpy/core/_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# /hps/nobackup/iqbal/mbhall/WHO-correspondence/.snakemake/conda/96fd00f4d1a3b1a39abc7b0eee92225d/lib/python3.10/site-packages/numpy/core/_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# /hps/nobackup/iqbal/mbhall/WHO-correspondence/.snakemake/conda/96fd00f4d1a3b1a39abc7b0eee92225d/lib/python3.10/site-packages/numpy/core/_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# /hps/nobackup/iqbal/mbhall/WHO-correspondence/.snakemake/conda/96fd00f4d1a3b1a39abc7b0eee92225d/lib/python3.10/site-packages/numpy/core/_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# /hps/nobackup/iqbal/mbhall/WHO-correspondence/.snakemake/conda/96fd00f4d1a3b1a39abc7b0eee92225d/lib/python3.10/site-packages/numpy/core/_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# /hps/nobackup/iqbal/mbhall/WHO-correspondence/.snakemake/conda/96fd00f4d1a3b1a39abc7b0eee92225d/lib/python3.10/site-packages/numpy/core/_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# /hps/nobackup/iqbal/mbhall/WHO-correspondence/.snakemake/conda/96fd00f4d1a3b1a39abc7b0eee92225d/lib/python3.10/site-packages/numpy/core/_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# /hps/nobackup/iqbal/mbhall/WHO-correspondence/.snakemake/conda/96fd00f4d1a3b1a39abc7b0eee92225d/lib/python3.10/site-packages/numpy/core/_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# /hps/nobackup/iqbal/mbhall/WHO-correspondence/.snakemake/conda/96fd00f4d1a3b1a39abc7b0eee92225d/lib/python3.10/site-packages/numpy/core/_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# /hps/nobackup/iqbal/mbhall/WHO-correspondence/.snakemake/conda/96fd00f4d1a3b1a39abc7b0eee92225d/lib/python3.10/site-packages/numpy/core/_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# /hps/nobackup/iqbal/mbhall/WHO-correspondence/.snakemake/conda/96fd00f4d1a3b1a39abc7b0eee92225d/lib/python3.10/site-packages/numpy/core/_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)

# %%
# fig.savefig("../../docs/submission/figure1.png")

# %%
for plot_path in plots:
    fig.savefig(plot_path)

# %%
print(table.to_latex(index=False).replace(".", "·").replace("l·", "l."))
# Out:
# \begin{tabular}{llllll}
# \toprule
#         Drug & Catalogue &     FN(R) &     FP(S) & Sensitivity (95\% CI) &  Specificity (95\% CI) \\
# \midrule
#     Amikacin &  WHO only &   48(311) &  38(3436) &     84·6\% (nan-nan\%) &      98·9\% (nan-nan\%) \\
#     Amikacin &     Paper &         - &         - &  77·3\% (74·9\%-79·5\%) &   99·0\% (98·9\%-99·2\%) \\
#     Amikacin &   Mykrobe &   49(311) &  16(3436) &     84·2\% (nan-nan\%) &      99·5\% (nan-nan\%) \\
#     Amikacin &  Combined &   48(311) &  38(3436) &     84·6\% (nan-nan\%) &      98·9\% (nan-nan\%) \\
#  Capreomycin &  WHO only &   99(319) &  42(3603) &     69·0\% (nan-nan\%) &      98·8\% (nan-nan\%) \\
#  Capreomycin &     Paper &         - &         - &  69·4\% (66·4\%-72·3\%) &   98·3\% (98·0\%-98·6\%) \\
#  Capreomycin &   Mykrobe &   98(319) &  39(3603) &     69·3\% (nan-nan\%) &      98·9\% (nan-nan\%) \\
#  Capreomycin &  Combined &   99(319) &  42(3603) &     69·0\% (nan-nan\%) &      98·8\% (nan-nan\%) \\
#    Delamanid &  WHO only &    42(42) &    0(492) &      0·0\% (nan-nan\%) &     100·0\% (nan-nan\%) \\
#    Delamanid &     Paper &         - &         - &    6·1\% (2·0\%-13·7\%) & 100·0\% (99·9\%-100·0\%) \\
#    Delamanid &   Mykrobe &      0(0) &      0(0) &                    - &                     - \\
#    Delamanid &  Combined &    42(42) &    0(492) &      0·0\% (nan-nan\%) &     100·0\% (nan-nan\%) \\
#   Ethambutol &  WHO only &  115(543) & 216(1636) &     78·8\% (nan-nan\%) &      86·8\% (nan-nan\%) \\
#   Ethambutol &     Paper &         - &         - &  86·7\% (85·7\%-87·6\%) &   93·3\% (93·0\%-93·6\%) \\
#   Ethambutol &   Mykrobe &  115(543) & 225(1636) &     78·8\% (nan-nan\%) &      86·2\% (nan-nan\%) \\
#   Ethambutol &  Combined &  109(543) & 227(1636) &     79·9\% (nan-nan\%) &      86·1\% (nan-nan\%) \\
#  Ethionamide &  WHO only &   44(229) &   98(562) &     80·8\% (nan-nan\%) &      82·6\% (nan-nan\%) \\
#  Ethionamide &     Paper &         - &         - &  75·7\% (74·1\%-77·3\%) &   91·4\% (90·8\%-91·9\%) \\
#  Ethionamide &   Mykrobe &      0(0) &      0(0) &                    - &                     - \\
#  Ethionamide &  Combined &   44(229) &   98(562) &     80·8\% (nan-nan\%) &      82·6\% (nan-nan\%) \\
#    Isoniazid &  WHO only & 418(2313) & 128(5361) &     81·9\% (nan-nan\%) &      97·6\% (nan-nan\%) \\
#    Isoniazid &     Paper &         - &         - &  91·2\% (90·7\%-91·7\%) &   98·4\% (98·2\%-98·6\%) \\
#    Isoniazid &   Mykrobe & 350(2313) & 116(5361) &     84·9\% (nan-nan\%) &      97·8\% (nan-nan\%) \\
#    Isoniazid &  Combined & 339(2313) & 141(5361) &     85·3\% (nan-nan\%) &      97·4\% (nan-nan\%) \\
#    Kanamycin &  WHO only &   77(361) &  36(3749) &     78·7\% (nan-nan\%) &      99·0\% (nan-nan\%) \\
#    Kanamycin &     Paper &         - &         - &  73·2\% (70·9\%-75·4\%) &   98·4\% (98·2\%-98·6\%) \\
#    Kanamycin &   Mykrobe &  119(361) &  22(3749) &     67·0\% (nan-nan\%) &      99·4\% (nan-nan\%) \\
#    Kanamycin &  Combined &   77(361) &  36(3749) &     78·7\% (nan-nan\%) &      99·0\% (nan-nan\%) \\
# Levofloxacin &  WHO only &    10(91) &    19(35) &     89·0\% (nan-nan\%) &      45·7\% (nan-nan\%) \\
# Levofloxacin &     Paper &         - &         - &  84·4\% (83·1\%-85·7\%) &   98·3\% (98·1\%-98·5\%) \\
# Levofloxacin &   Mykrobe &      0(0) &      0(0) &                    - &                     - \\
# Levofloxacin &  Combined &    10(91) &    19(35) &     89·0\% (nan-nan\%) &      45·7\% (nan-nan\%) \\
#    Linezolid &  WHO only &    12(12) &    0(412) &      0·0\% (nan-nan\%) &     100·0\% (nan-nan\%) \\
#    Linezolid &     Paper &         - &         - &  38·2\% (29·6\%-47·4\%) &   99·8\% (99·8\%-99·9\%) \\
#    Linezolid &   Mykrobe &      0(0) &      0(0) &                    - &                     - \\
#    Linezolid &  Combined &    12(12) &    0(412) &      0·0\% (nan-nan\%) &     100·0\% (nan-nan\%) \\
# Moxifloxacin &  WHO only &   24(262) & 129(4369) &     90·8\% (nan-nan\%) &      97·0\% (nan-nan\%) \\
# Moxifloxacin &     Paper &         - &         - &  87·7\% (86·2\%-89·2\%) &   91·6\% (91·0\%-92·1\%) \\
# Moxifloxacin &   Mykrobe &   26(262) & 125(4369) &     90·1\% (nan-nan\%) &      97·1\% (nan-nan\%) \\
# Moxifloxacin &  Combined &   24(262) & 129(4369) &     90·8\% (nan-nan\%) &      97·0\% (nan-nan\%) \\
# Pyrazinamide &  WHO only &  301(913) &  79(3712) &     67·0\% (nan-nan\%) &      97·9\% (nan-nan\%) \\
# Pyrazinamide &     Paper &         - &         - &  72·3\% (70·5\%-74·2\%) &   98·8\% (98·6\%-99·0\%) \\
# Pyrazinamide &   Mykrobe &  385(913) &  89(3712) &     57·8\% (nan-nan\%) &      97·6\% (nan-nan\%) \\
# Pyrazinamide &  Combined &  278(913) &  98(3712) &     69·6\% (nan-nan\%) &      97·4\% (nan-nan\%) \\
#   Rifampicin &  WHO only & 161(1856) & 147(6086) &     91·3\% (nan-nan\%) &      97·6\% (nan-nan\%) \\
#   Rifampicin &     Paper &         - &         - &  93·8\% (93·3\%-94·2\%) &   98·2\% (98·0\%-98·3\%) \\
#   Rifampicin &   Mykrobe & 170(1856) & 133(6086) &     90·8\% (nan-nan\%) &      97·8\% (nan-nan\%) \\
#   Rifampicin &  Combined & 161(1856) & 151(6086) &     91·3\% (nan-nan\%) &      97·5\% (nan-nan\%) \\
# Streptomycin &  WHO only &  181(689) & 127(1349) &     73·7\% (nan-nan\%) &      90·6\% (nan-nan\%) \\
# Streptomycin &     Paper &         - &         - &  82·4\% (81·3\%-83·5\%) &   95·4\% (95·0\%-95·8\%) \\
# Streptomycin &   Mykrobe &  201(689) &  93(1349) &     70·8\% (nan-nan\%) &      93·1\% (nan-nan\%) \\
# Streptomycin &  Combined &  156(689) & 151(1349) &     77·4\% (nan-nan\%) &      88·8\% (nan-nan\%) \\
# \bottomrule
# \end{tabular}
# /hps/scratch/lsf_tmpdir/hl-codon-04-01/ipykernel_2402347/3091391250.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(table.to_latex(index=False).replace(".", "·").replace("l·", "l."))

# %%
with open(outpath, "w") as fp:
    print(table.to_csv(index=False).replace(".", "·").replace("l·", "l."), file=fp)

# %%
for drug in set(table["Drug"]):
    print(drug)
    rows = table.query("Drug==@drug and Catalogue in ['Mykrobe', 'Combined']").sort_values("Catalogue", ascending=False)
    sn1 = rows["Sensitivity (95% CI)"].iloc[0].split()[0][:-1]
    if not sn1:
        continue
    sn1 = float(sn1)
    sn2 = float(rows["Sensitivity (95% CI)"].iloc[1].split()[0][:-1])
    sndiff = sn1-sn2
    sp1 = float(rows["Specificity (95% CI)"].iloc[0].split()[0][:-1])
    sp2 = float(rows["Specificity (95% CI)"].iloc[1].split()[0][:-1])
    spdiff = sp1-sp2
    print(f"Sn diff. {sndiff:.1f}\tSp diff. {spdiff:.1f}")
# Out:
# Linezolid
# Ethambutol
# Sn diff. -1.1	Sp diff. 0.1
# Levofloxacin
# Rifampicin
# Sn diff. -0.5	Sp diff. 0.3
# Delamanid
# Ethionamide
# Pyrazinamide
# Sn diff. -11.8	Sp diff. 0.2
# Amikacin
# Sn diff. -0.4	Sp diff. 0.6
# Isoniazid
# Sn diff. -0.4	Sp diff. 0.4
# Moxifloxacin
# Sn diff. -0.7	Sp diff. 0.1
# Streptomycin
# Sn diff. -6.6	Sp diff. 4.3
# Kanamycin
# Sn diff. -11.7	Sp diff. 0.4
# Capreomycin
# Sn diff. 0.3	Sp diff. 0.1
